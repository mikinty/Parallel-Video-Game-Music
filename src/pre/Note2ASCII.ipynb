# %%
from CONST import *
import music21
import glob

# %%
# Keep track of stats
doct = {}

# %%
# Convert files in directory
files = glob.glob("TEST\**\*.mid", recursive=True)
len(files)
# Out:
# 25

# %%
def analyzeFile(i):
    f = files[i] 

    # first, transpose the entire score into C major or A minor
    score = music21.converter.parse(f)
    key = score.analyze('key')
    mode = key.mode

    if mode == "major":
        halfSteps = majors[key.tonic.name]

    elif mode == "minor":
        halfSteps = minors[key.tonic.name]

    newscore = score.transpose(halfSteps)

    ### Now, print out score in our text format ###

    # Major/Minor
    print(mode)

    # Print parts
    for part in score.parts:
        # Find most common note
        l = [e.pitch for e in part.notes if e.isNote]
        c = [e.pitches[0] for e in part.notes if e.isChord]
        L = l+c

        # somehow have no elements in this part...
        if len(L) == 0:
            return

        m = max(set(L), key=L.count)

        print(STARTCODE)
        print(str(part.getInstrument()))

        # case on the most common pitch
        if m < music21.pitch.Pitch(MIDDLENOTE):
            print(BASSMARK)
        else:
            print(SOPRANOMARK)

        # prints out the notes
        for e in part.notesAndRests:
            d = "{:0.3f}".format(float(e.duration.quarterLength))

            if d in doct:
                doct[d] += 1
            else:
                doct[d] = 1

# %%
for i in range(1, 26):
    analyzeFile(i)
# Out:
# major
# S
# Reed Organ
# L
# S
# Reed Organ
# H
# S
# Reed Organ
# H
# S
# Piano
# L
# S
# Piano
# H
# S
# Piano
# H
# S
# Flute
# L
# S
# Flute
# H
# S
# Flute
# H
# major
# S
# Oboe
# H
# S
# Piano
# H
# S
# Acoustic Bass
# L
# S
# Piano
# H
# S
# Piano
# H
# S
# Harp
# H
# major
# minor
# S
# Ocarina
# H
# S
# StringInstrument
# H
# S
# Harp
# H
# S
# Piano
# H
# major
# S
# Trombone
# H
# S
# Piano
# H
# S
# Piano
# H
# S
# Piano
# L
# minor
# S
# Trumpet
# H
# S
# Trumpet
# H
# S
# Fretless Bass
# L
# minor
# S
# Piano
# H
# S
# Piano
# H
# S
# Piano
# L
# major
# S
# Piano
# H
# S
# Piano
# L
# major
# S
# Piano
# H
# S
# Piano
# L
# major
# S
# Marimba
# H
# S
# Piano
# L
# S
# Flute
# H
# S
# Marimba
# H
# minor
# S
# Flute
# H
# S
# Harp
# H
# S
# Piano
# L
# S
# Piano
# H
# S
# Piano
# H
# S
# Piano
# L
# S
# Electric Organ
# L
# S
# Electric Organ
# L
# major
# S
# Acoustic Bass
# L
# minor
# major
# S
# Clarinet
# H
# S
# Clarinet
# L
# S
# Piano
# L
# S
# Piano
# L
# minor
# S
# Recorder
# H
# S
# Harp
# L
# major
# S
# Guitar
# H
# S
# Guitar
# H
# S
# Contrabass
# H
# S
# StringInstrument
# H
# major
# S
# Piano
# H
# S
# Piano
# H
# S
# Ocarina
# H
# major
# S
# Piano
# H
# S
# Ocarina
# H
# S
# Harp
# H
# S
# StringInstrument
# H
# minor
# S
# Piano
# L
# S
# Piano
# H
# S
# Viola
# H
# S
# Violoncello
# H
# S
# Violin
# H
# major
# major
# S
# Electric Bass
# L
# S
# StringInstrument
# H
# S
# Trumpet
# H
# S
# Piano
# H
# S
# Piano
# H
# S
# Piano
# H
# S
# Timpani
# L
# S
# Piano
# L
# S
# Piano
# L
# minor
# minor
# S
# Harpsichord
# H
# S
# Harmonica
# H
# major
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-f171e115d455> in <module>()
#       1 for i in range(1, 26):
# ----> 2     analyzeFile(i)
#
# <ipython-input-45-db8adfb2b67e> in analyzeFile(i)
#       1 def analyzeFile(i):
# ----> 2     f = files[i]
#       3
#       4     # first, transpose the entire score into C major or A minor
#       5     score = music21.converter.parse(f)
#
# IndexError: list index out of range

# %%
L = []
for key in sorted(doct.keys()):
    L.append((float(key), int(doct[key])))

# %%
L.sort(key=lambda x: x[1])
L
# Out:
# [(15.0, 1),
#  (24.0, 1),
#  (26.0, 1),
#  (26.667, 1),
#  (48.0, 1),
#  (68.0, 1),
#  (152.0, 1),
#  (161.0, 1),
#  (258.333, 1),
#  (0.917, 2),
#  (3.25, 2),
#  (5.75, 2),
#  (7.75, 2),
#  (15.5, 2),
#  (17.0, 2),
#  (64.0, 2),
#  (131.0, 3),
#  (2.25, 4),
#  (5.5, 4),
#  (5.667, 4),
#  (1.25, 6),
#  (2.75, 6),
#  (9.0, 7),
#  (4.5, 8),
#  (12.0, 10),
#  (3.75, 11),
#  (16.0, 11),
#  (3.5, 14),
#  (3.333, 18),
#  (2.5, 19),
#  (5.0, 19),
#  (2.667, 20),
#  (7.5, 22),
#  (3.667, 35),
#  (7.0, 35),
#  (2.333, 36),
#  (6.0, 39),
#  (1.667, 40),
#  (1.75, 53),
#  (1.333, 105),
#  (8.0, 108),
#  (4.0, 114),
#  (3.0, 244),
#  (0.083, 260),
#  (0.167, 295),
#  (1.5, 344),
#  (0.75, 347),
#  (0.667, 541),
#  (2.0, 725),
#  (0.333, 753),
#  (1.0, 4067),
#  (0.25, 5034),
#  (0.5, 5082)]

# %%
A = [(1.333, 105),
 (8.0, 108),
 (4.0, 114),
 (3.0, 244),
 (0.083, 260),
 (0.167, 295),
 (1.5, 344),
 (0.75, 347),
 (0.667, 541),
 (2.0, 725),
 (0.333, 753),
 (1.0, 4067),
 (0.25, 5034),
 (0.5, 5082)]

A.sort(key=lambda x: x[0])
A
# Out:
# [(0.083, 260),
#  (0.167, 295),
#  (0.25, 5034),
#  (0.333, 753),
#  (0.5, 5082),
#  (0.667, 541),
#  (0.75, 347),
#  (1.0, 4067),
#  (1.333, 105),
#  (1.5, 344),
#  (2.0, 725),
#  (3.0, 244),
#  (4.0, 114),
#  (8.0, 108)]
