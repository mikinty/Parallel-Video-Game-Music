# %%
import glob
import os
import music21

# %%
# test file
f='MIDI/Basic/ff1menu.mid'
f1 = 'MIDI/Journey/overworld.mid'
score = music21.converter.parse(f)
s2 = music21.converter.parse(f1)

# %%
s2.analyze('key')
# Out:
# <music21.key.Key of C major>

# %%
# todo: add note onsets
def getMusicProperties(x):
    s = '';
    t='';
    s = str(x.pitch) + ", " + str(x.duration.type) + ", " + str(x.duration.quarterLength);
    s += ", "
    if x.tie != None:
        t = x.tie.type;
    s += t + ", " + str(x.pitch.ps) + ", " + str(x.octave); # + str(x.seconds)  # x.seconds not always there  
    return s

# %%
def printMusicProperties(score):
    for a in score.recurse().notes:

        if (a.isNote):
            x = a;
            s = getMusicProperties(x);
            print(s);

        if (a.isChord):
            for x in a._notes:
                s = getMusicProperties(x);
                print(s);

# %%
printMusicProperties(s2)
# Out:
# C5, half, 2.0, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, eighth, 1/3, , 72.0, 5
# B-4, 16th, 0.25, , 70.0, 4
# C5, half, 4/3, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, eighth, 1/3, , 72.0, 5
# B-4, 16th, 0.25, , 70.0, 4
# C5, quarter, 1.5, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# C5, eighth, 1/3, , 72.0, 5
# G4, 16th, 0.25, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# C5, quarter, 2/3, , 72.0, 5
# G4, quarter, 1.5, , 67.0, 4
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# D5, 16th, 0.25, , 74.0, 5
# E5, 16th, 0.25, , 76.0, 5
# F5, 16th, 0.25, , 77.0, 5
# G5, half, 2.0, , 79.0, 5
# G5, eighth, 1/3, , 79.0, 5
# G5, eighth, 1/3, , 79.0, 5
# G#5, eighth, 1/3, , 80.0, 5
# B-5, eighth, 1/3, , 82.0, 5
# C6, whole, 7/3, , 84.0, 6
# C6, eighth, 1/3, , 84.0, 6
# C6, eighth, 1/3, , 84.0, 6
# C6, eighth, 1/3, , 84.0, 6
# B-5, eighth, 1/3, , 82.0, 5
# G#5, eighth, 1/3, , 80.0, 5
# B-5, eighth, 1/3, , 82.0, 5
# G#5, eighth, 1/3, , 80.0, 5
# G5, half, 2.0, , 79.0, 5
# G5, quarter, 1.0, , 79.0, 5
# F5, eighth, 0.5, , 77.0, 5
# F5, 16th, 0.25, , 77.0, 5
# G5, 16th, 0.25, , 79.0, 5
# G#5, half, 2.0, , 80.0, 5
# G5, eighth, 0.5, , 79.0, 5
# F5, eighth, 0.5, , 77.0, 5
# E-5, eighth, 0.5, , 75.0, 5
# E-5, 16th, 0.25, , 75.0, 5
# F5, 16th, 0.25, , 77.0, 5
# G5, half, 2.0, , 79.0, 5
# F5, eighth, 0.5, , 77.0, 5
# E-5, eighth, 0.5, , 75.0, 5
# D5, eighth, 0.5, , 74.0, 5
# D5, 16th, 0.25, , 74.0, 5
# E5, 16th, 0.25, , 76.0, 5
# F#5, half, 2.0, , 78.0, 5
# A5, quarter, 1.0, , 81.0, 5
# G5, eighth, 1/3, , 79.0, 5
# G4, 16th, 0.25, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# C5, quarter, 2/3, , 72.0, 5
# G4, quarter, 1.5, , 67.0, 4
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# D5, 16th, 0.25, , 74.0, 5
# E5, 16th, 0.25, , 76.0, 5
# F5, 16th, 0.25, , 77.0, 5
# G5, half, 2.0, , 79.0, 5
# G5, eighth, 1/3, , 79.0, 5
# G5, eighth, 1/3, , 79.0, 5
# G#5, eighth, 1/3, , 80.0, 5
# B-5, eighth, 1/3, , 82.0, 5
# C6, half, 3.0, , 84.0, 6
# E-6, quarter, 1.0, , 87.0, 6
# D6, eighth, 0.5, , 86.0, 6
# B5, half, 5/3, , 83.0, 5
# G5, quarter, 1.0, , 79.0, 5
# G#5, complex, 2.25, , 80.0, 5
# C6, quarter, 1.0, , 84.0, 6
# B5, eighth, 0.5, , 83.0, 5
# G5, half, 5/3, , 79.0, 5
# G5, quarter, 1.0, , 79.0, 5
# G#5, half, 2.0, , 80.0, 5
# C6, quarter, 1.0, , 84.0, 6
# B5, eighth, 0.5, , 83.0, 5
# G5, half, 2.0, , 79.0, 5
# E5, quarter, 1.0, , 76.0, 5
# F5, half, 2.0, , 77.0, 5
# G#5, quarter, 1.0, , 80.0, 5
# G5, eighth, 0.5, , 79.0, 5
# E-5, half, 2.0, , 75.0, 5
# C5, quarter, 1.0, , 72.0, 5
# D5, eighth, 0.5, , 74.0, 5
# D5, 16th, 0.25, , 74.0, 5
# E5, 16th, 0.25, , 76.0, 5
# F#5, half, 2.0, , 78.0, 5
# A5, quarter, 1.0, , 81.0, 5
# G5, eighth, 1/3, , 79.0, 5
# G4, 16th, 0.25, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G4, eighth, 1/3, , 67.0, 4
# E4, half, 2.0, , 64.0, 4
# E4, 16th, 0.25, , 64.0, 4
# E4, 16th, 0.25, , 64.0, 4
# E4, 16th, 0.25, , 64.0, 4
# E4, 16th, 0.25, , 64.0, 4
# D4, eighth, 1/3, , 62.0, 4
# D4, 16th, 0.25, , 62.0, 4
# D4, half, 4/3, , 62.0, 4
# D4, 16th, 0.25, , 62.0, 4
# D4, 16th, 0.25, , 62.0, 4
# D4, 16th, 0.25, , 62.0, 4
# E-4, eighth, 1/3, , 63.0, 4
# E-4, 16th, 0.25, , 63.0, 4
# E-4, quarter, 1.5, , 63.0, 4
# E-4, 16th, 0.25, , 63.0, 4
# E-4, 16th, 0.25, , 63.0, 4
# E-4, 16th, 0.25, , 63.0, 4
# E-4, 16th, 0.25, , 63.0, 4
# E-4, eighth, 0.5, , 63.0, 4
# B3, 16th, 0.25, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# E4, quarter, 2/3, , 64.0, 4
# E4, eighth, 1/3, , 64.0, 4
# E4, eighth, 1/3, , 64.0, 4
# D4, eighth, 1/3, , 62.0, 4
# E4, eighth, 0.5, , 64.0, 4
# E4, 16th, 0.25, , 64.0, 4
# E4, 16th, 0.25, , 64.0, 4
# F4, 16th, 0.25, , 65.0, 4
# G4, 16th, 0.25, , 67.0, 4
# A4, 16th, 0.25, , 69.0, 4
# B-4, eighth, 0.75, , 70.0, 4
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# D5, 16th, 0.25, , 74.0, 5
# E5, 16th, 0.25, , 76.0, 5
# F5, 16th, 0.25, , 77.0, 5
# G5, eighth, 0.5, , 79.0, 5
# G5, eighth, 0.5, , 79.0, 5
# B-4, eighth, 1/3, , 70.0, 4
# C5, eighth, 1/3, , 72.0, 5
# D5, eighth, 1/3, , 74.0, 5
# E-5, eighth, 0.75, , 75.0, 5
# G#4, 16th, 0.25, , 68.0, 4
# G#4, 16th, 0.25, , 68.0, 4
# B-4, 16th, 0.25, , 70.0, 4
# C5, 16th, 0.25, , 72.0, 5
# D5, 16th, 0.25, , 74.0, 5
# E-5, eighth, 0.5, , 75.0, 5
# E-5, eighth, 0.5, , 75.0, 5
# E-5, eighth, 1/3, , 75.0, 5
# D5, eighth, 1/3, , 74.0, 5
# C5, eighth, 1/3, , 72.0, 5
# E-5, eighth, 1/3, , 75.0, 5
# B-4, eighth, 1/3, , 70.0, 4
# B-4, eighth, 1/3, , 70.0, 4
# B-4, eighth, 1/3, , 70.0, 4
# G#4, eighth, 1/3, , 68.0, 4
# B-4, eighth, 1/3, , 70.0, 4
# B-4, eighth, 1/3, , 70.0, 4
# B-4, eighth, 1/3, , 70.0, 4
# G#4, eighth, 1/3, , 68.0, 4
# B-4, eighth, 1/3, , 70.0, 4
# G#4, quarter, 2/3, , 68.0, 4
# G#4, 16th, 0.25, , 68.0, 4
# G4, 16th, 0.25, , 67.0, 4
# G#4, quarter, 2/3, , 68.0, 4
# B-4, 16th, 0.25, , 70.0, 4
# C5, quarter, 1.0, , 72.0, 5
# B-4, eighth, 0.5, , 70.0, 4
# G#4, eighth, 0.5, , 68.0, 4
# G4, quarter, 2/3, , 67.0, 4
# F4, 16th, 0.25, , 65.0, 4
# G4, quarter, 2/3, , 67.0, 4
# G#4, 16th, 0.25, , 68.0, 4
# B-4, quarter, 1.0, , 70.0, 4
# G#4, eighth, 0.5, , 68.0, 4
# G4, eighth, 0.5, , 67.0, 4
# F#4, quarter, 1.0, , 66.0, 4
# F#4, eighth, 0.75, , 66.0, 4
# G4, 16th, 0.25, , 67.0, 4
# A4, quarter, 2/3, , 69.0, 4
# B4, 16th, 0.25, , 71.0, 4
# C5, eighth, 0.5, , 72.0, 5
# D5, eighth, 0.5, , 74.0, 5
# B4, eighth, 1/3, , 71.0, 4
# B3, 16th, 0.25, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# E4, quarter, 2/3, , 64.0, 4
# E4, eighth, 1/3, , 64.0, 4
# E4, eighth, 1/3, , 64.0, 4
# D4, eighth, 1/3, , 62.0, 4
# E4, eighth, 0.5, , 64.0, 4
# E4, 16th, 0.25, , 64.0, 4
# E4, 16th, 0.25, , 64.0, 4
# F4, 16th, 0.25, , 65.0, 4
# G4, 16th, 0.25, , 67.0, 4
# A4, 16th, 0.25, , 69.0, 4
# B-4, eighth, 0.75, , 70.0, 4
# C5, 16th, 0.25, , 72.0, 5
# C5, 16th, 0.25, , 72.0, 5
# D5, 16th, 0.25, , 74.0, 5
# E5, 16th, 0.25, , 76.0, 5
# F5, 16th, 0.25, , 77.0, 5
# G5, eighth, 0.5, , 79.0, 5
# G5, eighth, 0.5, , 79.0, 5
# B-4, eighth, 1/3, , 70.0, 4
# C5, eighth, 1/3, , 72.0, 5
# D5, eighth, 1/3, , 74.0, 5
# E-5, half, 3.0, , 75.0, 5
# F#5, quarter, 1.0, , 78.0, 5
# F5, eighth, 0.5, , 77.0, 5
# D5, half, 5/3, , 74.0, 5
# B4, quarter, 1.0, , 71.0, 4
# C#5, complex, 2.25, , 73.0, 5
# E-5, quarter, 1.0, , 75.0, 5
# D5, eighth, 0.5, , 74.0, 5
# B4, half, 5/3, , 71.0, 4
# B4, quarter, 1.0, , 71.0, 4
# C#5, half, 2.0, , 73.0, 5
# E-5, quarter, 1.0, , 75.0, 5
# D5, eighth, 0.5, , 74.0, 5
# B4, half, 2.0, , 71.0, 4
# B4, quarter, 1.0, , 71.0, 4
# G#4, half, 2.0, , 68.0, 4
# C#5, quarter, 1.0, , 73.0, 5
# C5, eighth, 0.5, , 72.0, 5
# G4, half, 2.0, , 67.0, 4
# E-4, quarter, 1.0, , 63.0, 4
# F#4, quarter, 1.0, , 66.0, 4
# F#4, eighth, 0.75, , 66.0, 4
# G4, 16th, 0.25, , 67.0, 4
# A4, quarter, 2/3, , 69.0, 4
# B4, 16th, 0.25, , 71.0, 4
# C5, eighth, 0.5, , 72.0, 5
# D5, eighth, 0.5, , 74.0, 5
# B4, eighth, 1/3, , 71.0, 4
# B3, 16th, 0.25, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, 16th, 0.25, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# B3, eighth, 1/3, , 59.0, 3
# C3, quarter, 2/3, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C3, quarter, 2/3, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# B-2, quarter, 2/3, , 46.0, 2
# B-2, 16th, 0.25, , 46.0, 2
# B-2, 16th, 0.25, , 46.0, 2
# B-2, 16th, 0.25, , 46.0, 2
# B-2, quarter, 2/3, , 46.0, 2
# B-2, 16th, 0.25, , 46.0, 2
# B-2, 16th, 0.25, , 46.0, 2
# B-2, 16th, 0.25, , 46.0, 2
# G#2, quarter, 2/3, , 44.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# G#2, quarter, 2/3, , 44.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# G#2, eighth, 0.5, , 44.0, 2
# G2, eighth, 1/3, , 43.0, 2
# G2, eighth, 1/3, , 43.0, 2
# A2, eighth, 0.5, , 45.0, 2
# B2, eighth, 0.5, , 47.0, 2
# C3, eighth, 1/3, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# B-2, 16th, 0.25, , 46.0, 2
# C3, eighth, 1/3, , 48.0, 3
# C3, eighth, 1/3, , 48.0, 3
# B-2, eighth, 1/3, , 46.0, 2
# B-2, 16th, 0.25, , 46.0, 2
# B-2, 16th, 0.25, , 46.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# B-2, eighth, 1/3, , 46.0, 2
# B-2, eighth, 1/3, , 46.0, 2
# G#2, eighth, 1/3, , 44.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# F#2, 16th, 0.25, , 42.0, 2
# G#2, eighth, 1/3, , 44.0, 2
# G#2, eighth, 1/3, , 44.0, 2
# E-3, eighth, 0.5, , 51.0, 3
# E-3, eighth, 1/3, , 51.0, 3
# E-3, eighth, 1/3, , 51.0, 3
# C#3, eighth, 1/3, , 49.0, 3
# E-3, eighth, 0.5, , 51.0, 3
# E-3, eighth, 0.5, , 51.0, 3
# C#3, eighth, 0.5, , 49.0, 3
# C#3, eighth, 1/3, , 49.0, 3
# C#3, eighth, 1/3, , 49.0, 3
# C3, eighth, 1/3, , 48.0, 3
# C#3, eighth, 0.5, , 49.0, 3
# C#3, eighth, 1/3, , 49.0, 3
# C#3, eighth, 1/3, , 49.0, 3
# C#3, eighth, 1/3, , 49.0, 3
# C3, eighth, 0.5, , 48.0, 3
# C3, eighth, 1/3, , 48.0, 3
# C3, eighth, 1/3, , 48.0, 3
# B-2, eighth, 1/3, , 46.0, 2
# C3, eighth, 0.5, , 48.0, 3
# C3, eighth, 1/3, , 48.0, 3
# C3, eighth, 1/3, , 48.0, 3
# C3, eighth, 1/3, , 48.0, 3
# D3, eighth, 0.5, , 50.0, 3
# D3, eighth, 1/3, , 50.0, 3
# D3, eighth, 1/3, , 50.0, 3
# C3, eighth, 1/3, , 48.0, 3
# D3, eighth, 0.5, , 50.0, 3
# D3, eighth, 1/3, , 50.0, 3
# D3, eighth, 1/3, , 50.0, 3
# D3, eighth, 1/3, , 50.0, 3
# G2, eighth, 1/3, , 43.0, 2
# G2, eighth, 1/3, , 43.0, 2
# G2, eighth, 1/3, , 43.0, 2
# A2, eighth, 0.5, , 45.0, 2
# B2, eighth, 0.5, , 47.0, 2
# C3, eighth, 1/3, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# B-2, 16th, 0.25, , 46.0, 2
# C3, eighth, 1/3, , 48.0, 3
# C3, eighth, 1/3, , 48.0, 3
# B-2, eighth, 1/3, , 46.0, 2
# B-2, 16th, 0.25, , 46.0, 2
# B-2, 16th, 0.25, , 46.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# B-2, eighth, 1/3, , 46.0, 2
# B-2, eighth, 1/3, , 46.0, 2
# G#2, eighth, 1/3, , 44.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# G#2, 16th, 0.25, , 44.0, 2
# F#2, 16th, 0.25, , 42.0, 2
# G#2, eighth, 1/3, , 44.0, 2
# G#2, eighth, 1/3, , 44.0, 2
# G2, eighth, 1/3, , 43.0, 2
# G2, 16th, 0.25, , 43.0, 2
# G2, 16th, 0.25, , 43.0, 2
# F2, eighth, 1/3, , 41.0, 2
# G2, eighth, 1/3, , 43.0, 2
# G2, eighth, 1/3, , 43.0, 2
# F#2, 16th, 0.25, , 42.0, 2
# C3, 16th, 0.25, , 48.0, 3
# E-3, 16th, 0.25, , 51.0, 3
# F#3, 16th, 0.25, , 54.0, 3
# C4, 16th, 0.25, , 60.0, 4
# E-4, 16th, 0.25, , 63.0, 4
# F#4, eighth, 1/3, , 66.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G2, 16th, 0.25, , 43.0, 2
# G2, 16th, 0.25, , 43.0, 2
# G2, 16th, 0.25, , 43.0, 2
# G2, eighth, 1/3, , 43.0, 2
# F#2, 16th, 0.25, , 42.0, 2
# C3, 16th, 0.25, , 48.0, 3
# E-3, 16th, 0.25, , 51.0, 3
# F#3, 16th, 0.25, , 54.0, 3
# C4, 16th, 0.25, , 60.0, 4
# E-4, 16th, 0.25, , 63.0, 4
# F#4, eighth, 1/3, , 66.0, 4
# G4, eighth, 1/3, , 67.0, 4
# G2, 16th, 0.25, , 43.0, 2
# G2, 16th, 0.25, , 43.0, 2
# G2, 16th, 0.25, , 43.0, 2
# G2, eighth, 1/3, , 43.0, 2
# C#3, eighth, 1/3, , 49.0, 3
# C#3, 16th, 0.25, , 49.0, 3
# C#3, 16th, 0.25, , 49.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C#3, eighth, 1/3, , 49.0, 3
# C#3, 16th, 0.25, , 49.0, 3
# C#3, 16th, 0.25, , 49.0, 3
# C#3, 16th, 0.25, , 49.0, 3
# C3, eighth, 1/3, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# B-2, 16th, 0.25, , 46.0, 2
# C3, eighth, 1/3, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# C3, 16th, 0.25, , 48.0, 3
# D3, eighth, 1/3, , 50.0, 3
# D3, 16th, 0.25, , 50.0, 3
# D3, 16th, 0.25, , 50.0, 3
# D3, 16th, 0.25, , 50.0, 3
# D3, eighth, 1/3, , 50.0, 3
# D3, 16th, 0.25, , 50.0, 3
# D3, 16th, 0.25, , 50.0, 3
# D3, 16th, 0.25, , 50.0, 3
# G2, eighth, 1/3, , 43.0, 2
# G2, eighth, 1/3, , 43.0, 2
# G2, eighth, 1/3, , 43.0, 2
# A2, eighth, 0.5, , 45.0, 2
# B2, eighth, 0.5, , 47.0, 2
# E2, quarter, 2/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, quarter, 2/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, quarter, 2/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, 16th, 0.25, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2
# E2, eighth, 1/3, , 40.0, 2

# %%
# For each part, look at notes
a = []
for p in s2.parts:
    a.append(p)

# %%
a[0].elements
# Out:
# (<music21.instrument.Clarinet Clarinet>,
#  <music21.instrument.Clarinet Clarinet>,
#  <music21.tempo.MetronomeMark Quarter=148.0>,
#  <music21.key.Key of C major>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note B->,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note B->,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G#>,
#  <music21.note.Note B->,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note B->,
#  <music21.note.Note G#>,
#  <music21.note.Note B->,
#  <music21.note.Rest rest>,
#  <music21.note.Note G#>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note G#>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note E->,
#  <music21.note.Note E->,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note E->,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G#>,
#  <music21.note.Note B->,
#  <music21.note.Note C>,
#  <music21.note.Note E->,
#  <music21.note.Note D>,
#  <music21.note.Rest rest>,
#  <music21.note.Note B>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G#>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Note B>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G#>,
#  <music21.note.Rest rest>,
#  <music21.note.Note C>,
#  <music21.note.Note B>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G#>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note E->,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Note G>,
#  <music21.note.Rest rest>,
#  <music21.note.Note G>)

# %%
# Get the name of the part
str(a[0].getInstrument())
# Out:
# 'Clarinet'

# %%
# Figure out which voice, soprano, treble, tenor, or bass
a[0].sort()
l = [e.pitch for e in a[0].notes]
m = max(set(l), key=l.count)
music21.pitch.Pitch('C#5') < m
# Out:
# False

# %%
# prints out the notes
for e in a[1].notesAndRests:
    if e.isNote:
        print(e.pitch, end=', ')
    else:
        print('R', end=', ')
    print("{:0.3f}".format(float(e.duration.quarterLength)))
# Out:
# E4, 2.000
# R, 0.667
# E4, 0.250
# R, 0.083
# E4, 0.250
# R, 0.083
# E4, 0.250
# R, 0.083
# E4, 0.250
# R, 0.083
# D4, 0.333
# R, 0.333
# D4, 0.250
# R, 0.083
# D4, 1.333
# R, 0.667
# D4, 0.250
# R, 0.083
# D4, 0.250
# R, 0.083
# D4, 0.250
# R, 0.083
# E-4, 0.333
# R, 0.333
# E-4, 0.250
# R, 0.083
# E-4, 1.500
# R, 0.167
# E-4, 0.250
# R, 0.083
# E-4, 0.250
# R, 0.083
# E-4, 0.250
# R, 0.083
# E-4, 0.250
# R, 0.083
# E-4, 0.500
# B3, 0.250
# B3, 0.250
# B3, 0.333
# R, 0.167
# B3, 0.250
# B3, 0.250
# B3, 0.333
# R, 0.167
# B3, 0.250
# B3, 0.250
# B3, 0.333
# R, 0.167
# B3, 0.333
# R, 0.167
# E4, 0.667
# R, 0.333
# E4, 0.333
# E4, 0.333
# D4, 0.333
# E4, 0.500
# R, 0.250
# E4, 0.250
# E4, 0.250
# F4, 0.250
# G4, 0.250
# A4, 0.250
# B-4, 0.750
# C5, 0.250
# C5, 0.250
# D5, 0.250
# E5, 0.250
# F5, 0.250
# G5, 0.500
# G5, 0.500
# B-4, 0.333
# C5, 0.333
# D5, 0.333
# E-5, 0.750
# G#4, 0.250
# G#4, 0.250
# B-4, 0.250
# C5, 0.250
# D5, 0.250
# E-5, 0.500
# E-5, 0.500
# E-5, 0.333
# D5, 0.333
# C5, 0.333
# E-5, 0.333
# R, 0.333
# B-4, 0.333
# B-4, 0.333
# B-4, 0.333
# G#4, 0.333
# B-4, 0.333
# R, 0.333
# B-4, 0.333
# B-4, 0.333
# G#4, 0.333
# B-4, 0.333
# G#4, 0.667
# G#4, 0.250
# G4, 0.250
# G#4, 0.667
# R, 0.083
# B-4, 0.250
# C5, 1.000
# B-4, 0.500
# G#4, 0.500
# G4, 0.667
# R, 0.083
# F4, 0.250
# G4, 0.667
# R, 0.083
# G#4, 0.250
# B-4, 1.000
# G#4, 0.500
# G4, 0.500
# F#4, 1.000
# F#4, 0.750
# G4, 0.250
# A4, 0.667
# R, 0.083
# B4, 0.250
# C5, 0.500
# D5, 0.500
# B4, 0.333
# R, 0.167
# B3, 0.250
# B3, 0.250
# B3, 0.333
# R, 0.167
# B3, 0.250
# B3, 0.250
# B3, 0.333
# R, 0.167
# B3, 0.250
# B3, 0.250
# B3, 0.333
# R, 0.167
# B3, 0.333
# R, 0.167
# E4, 0.667
# R, 0.333
# E4, 0.333
# E4, 0.333
# D4, 0.333
# E4, 0.500
# R, 0.250
# E4, 0.250
# E4, 0.250
# F4, 0.250
# G4, 0.250
# A4, 0.250
# B-4, 0.750
# C5, 0.250
# C5, 0.250
# D5, 0.250
# E5, 0.250
# F5, 0.250
# G5, 0.500
# G5, 0.500
# B-4, 0.333
# C5, 0.333
# D5, 0.333
# E-5, 3.000
# F#5, 1.000
# F5, 0.500
# R, 0.500
# D5, 1.667
# R, 0.333
# B4, 1.000
# C#5, 2.250
# R, 0.750
# E-5, 1.000
# D5, 0.500
# R, 0.500
# B4, 1.667
# R, 0.333
# B4, 1.000
# C#5, 2.000
# R, 1.000
# E-5, 1.000
# D5, 0.500
# R, 0.500
# B4, 2.000
# B4, 1.000
# G#4, 2.000
# R, 1.000
# C#5, 1.000
# C5, 0.500
# R, 0.500
# G4, 2.000
# E-4, 1.000
# F#4, 1.000
# F#4, 0.750
# G4, 0.250
# A4, 0.667
# R, 0.083
# B4, 0.250
# C5, 0.500
# D5, 0.500
# B4, 0.333
# R, 0.167
# B3, 0.250
# B3, 0.250
# B3, 0.333
# R, 0.167
# B3, 0.250
# B3, 0.250
# B3, 0.333
# R, 0.167
# B3, 0.250
# B3, 0.250
# B3, 0.333
# R, 0.167
# B3, 0.333

# %%
float(b)
# Out:
# 0.3333333333333333
